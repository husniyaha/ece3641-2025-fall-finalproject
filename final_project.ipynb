# %% [markdown]
# ## Final Project
# (executed cells have errors because of the imports)

# %% [markdown]
# ## QUICK START: How to Execute the Robot Typing Code?
#
# Make sure before you run it:
#
# Power on your ArmPi Pro robot
# Ensure roslaunch start.launch
# Wait a few seconds for the servo controller to initialize
#
# Then run the python3 command below on the raspberrypi:

# %%
rosrun Terminator.py
# Out:
#   Cell In[1], line 1
#     rosrun Terminator.py
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Code:

# %% [markdown]
# ## Important Libraries

# %%
import sys
import time
import rospy
from kinematics import ik_transform
from armpi_pro import bus_servo_control
from hiwonder_servo_msgs.msg import MultiRawIdPosDur
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import sys
#       2 import time
# ----> 3 import rospy
#       4 from kinematics import ik_transform
#       5 from armpi_pro import bus_servo_control
#
# ModuleNotFoundError: No module named 'rospy'

# %% [markdown]
# ## Dictionary

# %%
servo_positions = {
    1: {'servo1': 395, 'servo2': 472, 'servo3': 109, 'servo4': 198, 'servo5': 223, 'servo6': 548},
    2: {'servo1': 800, 'servo2': 472, 'servo3': 119, 'servo4': 199, 'servo5': 125, 'servo6': 555},
    3: {'servo1': 800, 'servo2': 472, 'servo3': 337, 'servo4': 419, 'servo5': 127, 'servo6': 571},
    4: {'servo1': 800, 'servo2': 472, 'servo3': 333, 'servo4': 336, 'servo5': 137, 'servo6': 566},
    5: {'servo1': 800, 'servo2': 472, 'servo3': 263, 'servo4': 372, 'servo5': 124, 'servo6': 555},
    6: {'servo1': 800, 'servo2': 472, 'servo3': 263, 'servo4': 419, 'servo5': 124, 'servo6': 555},
    7: {'servo1': 800, 'servo2': 472, 'servo3': 216, 'servo4': 249, 'servo5': 123, 'servo6': 554},
    8: {'servo1': 800, 'servo2': 472, 'servo3': 244, 'servo4': 375, 'servo5': 123, 'servo6': 549},
    9: {'servo1': 800, 'servo2': 472, 'servo3': 243, 'servo4': 419, 'servo5': 125, 'servo6': 546},
    10: {'servo1': 800, 'servo2': 472, 'servo3': 244, 'servo4': 382, 'servo5': 125, 'servo6': 536},
    11: {'servo1': 800, 'servo2': 472, 'servo3': 243, 'servo4': 252, 'servo5': 125, 'servo6': 537},
    12: {'servo1': 800, 'servo2': 472, 'servo3': 245, 'servo4': 419, 'servo5': 123, 'servo6': 525},
    13: {'servo1': 800, 'servo2': 472, 'servo3': 243, 'servo4': 254, 'servo5': 124, 'servo6': 514},
    14: {'servo1': 800, 'servo2': 472, 'servo3': 244, 'servo4': 381, 'servo5': 123, 'servo6': 510},
    15: {'servo1': 800, 'servo2': 472, 'servo3': 170, 'servo4': 419, 'servo5': 125, 'servo6': 511},
}

# %% [markdown]
# ## Move to key

# %%
def move_to_position(position_number, duration=1000):
    if position_number not in servo_positions:
        print(f"Position {position_number} not found!")
        return False
    
    servo_data = servo_positions[position_number]
    bus_servo_control.set_servos(joints_pub, duration, ((1, servo_data['servo1']), (2, servo_data['servo2']), 
                    (3, servo_data['servo3']), (4, servo_data['servo4']), (5, servo_data['servo5']), (6, servo_data['servo6'])))
    return True

# %% [markdown]
# ## Main

# %%
if __name__=='__main__':
    rospy.init_node('Robot_Typing', log_level=rospy.DEBUG)
    rospy.on_shutdown(stop)
    joints_pub = rospy.Publisher('/servo_controllers/port_id_1/multi_id_pos_dur', MultiRawIdPosDur, queue_size=1)
    rospy.sleep(1.0)

    print("Moving to pen position...")
    move_to_position(1, duration=1000)
    time.sleep(1.0)
    
    print("Gripping pen...")
    move_to_position(2, duration=1000)
    time.sleep(1.0)

    print("Pressing Key 1...")
    move_to_position(3, duration=1000)
    time.sleep(0.5)
    move_to_position(4, duration=1000)
    time.sleep(0.3)
    move_to_position(5, duration=1000)
    time.sleep(0.5)

    print("Pressing Key 2...")
    move_to_position(6, duration=1000)
    time.sleep(0.5)
    move_to_position(7, duration=1000)
    time.sleep(0.3)
    move_to_position(8, duration=1000)
    time.sleep(0.5)

    print("Pressing Key 3...")
    move_to_position(9, duration=1000)
    time.sleep(0.5)
    move_to_position(10, duration=1000)
    time.sleep(0.3)
    move_to_position(11, duration=1000)
    time.sleep(0.5)

    print("Pressing Key 4...")
    move_to_position(12, duration=1000)
    time.sleep(0.5)
    move_to_position(13, duration=1000)
    time.sleep(0.3)
    move_to_position(14, duration=1000)
    time.sleep(0.5)

    print("Pressing Key 5...")
    move_to_position(15, duration=1000)
    time.sleep(0.5)
    time.sleep(1.0)

    print("Releasing pen and returning to neutral...")
    move_to_position(2, duration=1000)
    time.sleep(2.0)

    print("Typing task complete!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 if __name__=='__main__':
# ----> 2     rospy.init_node('Robot_Typing', log_level=rospy.DEBUG)
#       3     rospy.on_shutdown(stop)
#       4     joints_pub = rospy.Publisher('/servo_controllers/port_id_1/multi_id_pos_dur', MultiRawIdPosDur, queue_size=1)
#
# NameError: name 'rospy' is not defined
